# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
fig, ax = plt.subplots()
x = np.linspace(15,95)
for i in np.arange(50,70,3):
    y = 1/(1+np.exp(-0.3*(x-i)))
    ax.plot(x,y)
ax.set_xlabel('Temperature [°C]')
ax.set_ylabel("Fluorescence Ratio [AU]")
fig.savefig('fig/ndsf.png', dpi=200, bbox_inches='tight')

# %% [markdown]
# # Protein fibril equillibration
# The reaction scheme for fibril formation can be described by the following equation:
# $$M+F \rightleftharpoons F$$
#
# ![](fig/ndsf.png)

# %% [markdown]
# # The second slide

# %% [markdown]
# 1. Dont do it

# %% [markdown]
# 2. exactly

# %% [markdown]
# This part tests the notes that you will see.
